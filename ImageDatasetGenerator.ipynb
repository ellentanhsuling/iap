# %% [markdown]
# <a href="https://colab.research.google.com/github/ellentanhsuling/iap/blob/main/ImageDatasetGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import packages

# %%
#download image downloader package
# !pip install bing-image-downloader

# %%
#make a folder in Drive
# !mkdir 'drive/MyDrive/images'
# Out:
# mkdir: cannot create directory ‘drive/MyDrive/images’: File exists

# %% [markdown]
# # Bing Image Downloader Code

# %%
#this will usually show an error cos Bing will time you out but usually getting 60 images is no problem
from bing_image_downloader import downloader
downloader.download("motorcycle", limit = 100, output_dir='drive/MyDrive/images')
# Out:
# [%] Downloading Images to /content/drive/MyDrive/images/motorcycle
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://www.motopinas.com/images/posts/post12933.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://1.bp.blogspot.com/-IejL8GXxXck/UPZkKrGovuI/AAAAAAAAIqQ/Qyp0Y-_Qik0/s1600/2013-CanAm-Spyder-ST-S-motorcycle-photos-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.bikebros.co.jp/vb_img/procustom/sports/img/35/main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://www.bikebros.co.jp/vb_img/procustom/naked/img/111/main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.lux-review.com/wp-content/uploads/2021/09/Motorbike.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.bulldock.jp/gtm/z1000mk2/007/img/main.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #7 from https://wallpapercave.com/wp/sTDIoNT.jpg
# ...

# %%
#this will usually show an error cos Bing will time you out but usually getting 60 images is no problem
from bing_image_downloader import downloader
downloader.download("car", limit = 100, output_dir='drive/MyDrive/images')
# Out:
# [%] Downloading Images to /content/drive/MyDrive/images/car
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://cdn.vox-cdn.com/thumbor/IZ7fpJNSeEO1v2vNapVlLYlCWzc=/214x0:1037x549/1200x800/filters:focal(214x0:1037x549)/cdn.vox-cdn.com/uploads/chorus_image/image/45200072/new-ford-gt-supercar-0006.0.0.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://1.bp.blogspot.com/-NYTuyZpJM4Q/T7-_weFK2II/AAAAAAAAAIg/JfHOAwQuUXM/s1600/2013%2Bf.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.wallpapersafari.com/37/15/6Fk0sM.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://4.bp.blogspot.com/-W2rT6DiYko0/UOol6OWBfVI/AAAAAAAAE_E/3l3jKDQiAGo/s1600/738337_492628620787429_400049271_o.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.newcarreleasedates.com/uploads/1/8/5/5/1855303/6107158_orig.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# # Error Checking

# %%
#ERROR CHECK1 (can't find file)
from PIL import Image
import os
directory = r'drive/MyDrive/images/car/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        print(filename)
# Out:
# Image_29.png
# Image_94.png
# Image_63.png
# Image_92.png
# Image_39.png
# Image_85.png
# Image_77.png
# Image_65.png
# Image_46.png
# Image_41.png
# Image_40.png
# Image_90.png

# %%
#ERROR CHECK1 (can't find file)
from PIL import Image
import os
directory = r'drive/MyDrive/images/motorcycle/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        print(filename)
# Out:
# Image_59.png

# %%
#ERROR CHECK2 (can't find file because open function needs full path name)
from PIL import Image
import os
directory = r'drive/MyDrive/images/car/'
path = 'drive/MyDrive/images/car/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        im = Image.open(path + filename)


#PROJECT_PATH = 'C:\\cimtrack_v1'
#im = Image.open(PROJECT_PATH + '\\ST.jpg')

# %%
#ERROR CHECK2 (can't find file because open function needs full path name)
from PIL import Image
import os
directory = r'drive/MyDrive/images/motorcycle/'
path = 'drive/MyDrive/images/motorcycle/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        im = Image.open(path + filename)


#PROJECT_PATH = 'C:\\cimtrack_v1'
#im = Image.open(PROJECT_PATH + '\\ST.jpg')

# %% [markdown]
# # Convert images to JPG

# %%
#Standardization 1: convert all to JPG (drop transparency) for 'motorcycle' folder (first search term)
from PIL import Image
import os
directory = r'drive/MyDrive/images/motorcycle/'
path = 'drive/MyDrive/images/motorcycle/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        prefix = filename.split(".png")[0]
        im = Image.open(path + filename)
        rgb_im = im.convert('RGB')
        rgb_im.save(path + prefix+'.jpg')
        os.remove(path + prefix + '.png')
    else:
        continue

#rgb_im = im.convert('RGB')
#rgb_im.save('audacious.jpg')

# %%
#Standardization 1: convert all to JPG (drop transparency) for 'car' folder (first search term)
from PIL import Image
import os
directory = r'drive/MyDrive/images/car/'
path = 'drive/MyDrive/images/car/'
for filename in os.listdir(directory):
    if filename.endswith(".png"):
        prefix = filename.split(".png")[0]
        im = Image.open(path + filename)
        rgb_im = im.convert('RGB')
        rgb_im.save(path + prefix+'.jpg')
        os.remove(path + prefix + '.png')
    else:
        continue

#rgb_im = im.convert('RGB')
#rgb_im.save('audacious.jpg')

# %% [markdown]
# # Data Augmentation

# %%
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image  # Import the Image class from PIL

# Define the input and output folders
input_folder = 'drive/MyDrive/images/motorcycle'
output_folder = 'drive/MyDrive/images/AUGmotorcycle'
os.makedirs(output_folder, exist_ok=True)

# Create an instance of the ImageDataGenerator with desired augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=20,      # Randomly rotate images within the range of 20 degrees
    width_shift_range=0.1,  # Randomly shift images horizontally within 10% of the total width
    height_shift_range=0.1, # Randomly shift images vertically within 10% of the total height
    shear_range=0.2,        # Randomly apply shear transformation
    zoom_range=0.2,         # Randomly zoom in or out on images
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'     # Fill any newly created pixels after rotation or shifting
)

# Generate augmented images and save them to the output folder
for file_name in os.listdir(input_folder):
    # Construct the full path to the input image file
    input_image_path = os.path.join(input_folder, file_name)

    # Load the input image
    input_image = Image.open(input_image_path)
    input_image = input_image.convert('RGB')  # Convert to RGB if the image is in grayscale

    # Reshape the image to a 4D tensor with shape (1, height, width, channels)
    input_image = np.array(input_image)
    input_image = np.expand_dims(input_image, axis=0)

    # Generate augmented images
    augmented_images = datagen.flow(input_image, batch_size=1, save_to_dir=output_folder, save_prefix='aug_', save_format='jpg')

    # Generate a desired number of augmented images per input image
    num_augmented_images = 5
    for _ in range(num_augmented_images):
        augmented_image = augmented_images.next()

# %%
#rename all files in AUGMENTED folder
import os

# Specify the path to the folder containing the files
folder_path = 'drive/MyDrive/images/AUGmotorcycle'

# Get the list of files in the folder
file_list = os.listdir(folder_path)

# Iterate over each file and rename it
for i, file_name in enumerate(file_list):
    # Specify the new name for each file
    new_file_name = f'{i}.jpg'  # Modify the naming convention as per your requirements

    # Construct the full path for the original and new file names
    original_file_path = os.path.join(folder_path, file_name)
    new_file_path = os.path.join(folder_path, new_file_name)

    # Rename the file
    os.rename(original_file_path, new_file_path)

# %%
import numpy as np
import os
from keras.preprocessing.image import ImageDataGenerator
from PIL import Image  # Import the Image class from PIL

# Define the input and output folders
input_folder = 'drive/MyDrive/images/car'
output_folder = 'drive/MyDrive/images/AUGcar'
os.makedirs(output_folder, exist_ok=True)

# Create an instance of the ImageDataGenerator with desired augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=20,      # Randomly rotate images within the range of 20 degrees
    width_shift_range=0.1,  # Randomly shift images horizontally within 10% of the total width
    height_shift_range=0.1, # Randomly shift images vertically within 10% of the total height
    shear_range=0.2,        # Randomly apply shear transformation
    zoom_range=0.2,         # Randomly zoom in or out on images
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'     # Fill any newly created pixels after rotation or shifting
)

# Generate augmented images and save them to the output folder
for file_name in os.listdir(input_folder):
    # Construct the full path to the input image file
    input_image_path = os.path.join(input_folder, file_name)

    # Load the input image
    input_image = Image.open(input_image_path)
    input_image = input_image.convert('RGB')  # Convert to RGB if the image is in grayscale

    # Reshape the image to a 4D tensor with shape (1, height, width, channels)
    input_image = np.array(input_image)
    input_image = np.expand_dims(input_image, axis=0)

    # Generate augmented images
    augmented_images = datagen.flow(input_image, batch_size=1, save_to_dir=output_folder, save_prefix='aug_', save_format='jpg')

    # Generate a desired number of augmented images per input image
    num_augmented_images = 3
    for _ in range(num_augmented_images):
        augmented_image = augmented_images.next()
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
#rename all files in AUGMENTED folder
import os

# Specify the path to the folder containing the files
folder_path = 'drive/MyDrive/images/AUGcar'

# Get the list of files in the folder
file_list = os.listdir(folder_path)

# Iterate over each file and rename it
for i, file_name in enumerate(file_list):
    # Specify the new name for each file
    new_file_name = f'{i}.jpg'  # Modify the naming convention as per your requirements

    # Construct the full path for the original and new file names
    original_file_path = os.path.join(folder_path, file_name)
    new_file_path = os.path.join(folder_path, new_file_name)

    # Rename the file
    os.rename(original_file_path, new_file_path)

# %% [markdown]
# # STANDARDIZATION

# %%
#For motorcycle

import os
from PIL import Image
import numpy as np

# Define the desired image size
image_size = (224, 224)

# Create a new folder to store the standardized images
output_folder = 'drive/MyDrive/images/NORMmotorcycle'
os.makedirs(output_folder, exist_ok=True)

# Load and resize the images
def resize_image(image_path):
    image = Image.open(image_path)
    image = image.resize(image_size)
    return image

# Normalize the pixel values
def normalize_image(image):
    # Convert the image to a NumPy array
    image_array = np.array(image)

    # Normalize the pixel values using mean normalization
    mean = np.mean(image_array)
    std = np.std(image_array)
    normalized_image = (image_array - mean) / std

    return normalized_image

# Get the list of image files in the folder
input_folder = 'drive/MyDrive/images/AUGmotorcycle'
image_files = os.listdir(input_folder)

# Resize and normalize each image in the folder
for file_name in image_files:
    # Construct the full path to the image file
    image_path = os.path.join(input_folder, file_name)

    # Resize the image
    resized_image = resize_image(image_path)

    # Normalize the pixel values
    normalized_image = normalize_image(resized_image)

    # Save the standardized image to the output folder
    output_path = os.path.join(output_folder, file_name)
    Image.fromarray((normalized_image * 255).astype(np.uint8)).save(output_path)

# %%
#For car

import os
from PIL import Image
import numpy as np

# Define the desired image size
image_size = (224, 224)

# Create a new folder to store the standardized images
output_folder = 'drive/MyDrive/images/NORMcar'
os.makedirs(output_folder, exist_ok=True)

# Load and resize the images
def resize_image(image_path):
    image = Image.open(image_path)
    image = image.resize(image_size)
    return image

# Normalize the pixel values
def normalize_image(image):
    # Convert the image to a NumPy array
    image_array = np.array(image)

    # Normalize the pixel values using mean normalization
    mean = np.mean(image_array)
    std = np.std(image_array)
    normalized_image = (image_array - mean) / std

    return normalized_image

# Get the list of image files in the folder
input_folder = 'drive/MyDrive/images/AUGcar'
image_files = os.listdir(input_folder)

# Resize and normalize each image in the folder
for file_name in image_files:
    # Construct the full path to the image file
    image_path = os.path.join(input_folder, file_name)

    # Resize the image
    resized_image = resize_image(image_path)

    # Normalize the pixel values
    normalized_image = normalize_image(resized_image)

    # Save the standardized image to the output folder
    output_path = os.path.join(output_folder, file_name)
    Image.fromarray((normalized_image * 255).astype(np.uint8)).save(output_path)

# %% [markdown]
# # STANDARDIZATION WITH CONVERSION TO CSV

# %%
import os
import csv
from PIL import Image
import numpy as np

# Define the desired image size
image_size = (200, 200)

# Create a new folder to store the standardized images
output_folder = 'drive/MyDrive/images/vehiclecsv'
os.makedirs(output_folder, exist_ok=True)

# Load and resize the images
def resize_image(image_path):
    image = Image.open(image_path)
    image = image.resize(image_size)
    return image

# Normalize the pixel values
def normalize_image(image):
    # Convert the image to a NumPy array
    image_array = np.array(image)

    # Normalize the pixel values using mean normalization
    mean = np.mean(image_array)
    std = np.std(image_array)
    normalized_image = (image_array - mean) / std

    return normalized_image

# Get the list of image files in the first folder (motorcycle)
motorcycle_folder = 'drive/MyDrive/images/AUGmotorcycle'
motorcycle_files = os.listdir(motorcycle_folder)

# Get the list of image files in the second folder (car)
car_folder = 'drive/MyDrive/images/AUGcar'
car_files = os.listdir(car_folder)

# Initialize a list to store the image data and labels
image_data = []
labels = []

# Resize and normalize each image in the motorcycle folder
for file_name in motorcycle_files:
    # Construct the full path to the image file
    image_path = os.path.join(motorcycle_folder, file_name)

    # Resize the image
    resized_image = resize_image(image_path)

    # Normalize the pixel values
    normalized_image = normalize_image(resized_image)

    # Save the standardized image to the output folder
    output_path = os.path.join(output_folder, file_name)
    Image.fromarray((normalized_image * 255).astype(np.uint8)).save(output_path)

    # Flatten the image array to a 1D array
    flattened_image = normalized_image.flatten()

    # Add the flattened image array and label to the lists
    image_data.append(flattened_image)
    labels.append(1)  # Change label for motorcycle to 1

# Resize and normalize each image in the car folder
for file_name in car_files:
    # Construct the full path to the image file
    image_path = os.path.join(car_folder, file_name)

    # Resize the image
    resized_image = resize_image(image_path)

    # Normalize the pixel values
    normalized_image = normalize_image(resized_image)

    # Save the standardized image to the output folder
    output_path = os.path.join(output_folder, file_name)
    Image.fromarray((normalized_image * 255).astype(np.uint8)).save(output_path)

    # Flatten the image array to a 1D array
    flattened_image = normalized_image.flatten()

    # Add the flattened image array and label to the lists
    image_data.append(flattened_image)
    labels.append(0)  # Change label for honeydew to 0

# Convert the image data and labels lists to NumPy arrays
image_data = np.array(image_data)
labels = np.array(labels)

# Combine the image data and labels arrays into a single array
combined_data = np.column_stack((image_data, labels))

# Define the column names for the CSV file
column_names = ['pixel_' + str(i) for i in range(image_data.shape[1])] + ['label']

# Define the CSV file path
csv_file_path = 'drive/MyDrive/images/vehiclecsv/image_data.csv'

# Save the combined data as a CSV file
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(column_names)  # Write the column names to the CSV file
    writer.writerows(combined_data)

# %% [markdown]
# # TRAIN AND TEST

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, MaxPooling2D, Dense
from tensorflow.keras.losses import categorical_crossentropy

# %%
data=pd.read_csv('drive/MyDrive/images/vehiclecsv/image_data.csv')

# %%
data.shape
# Out:
# (786, 120001)

# %%
data.head()
# Out:
#     pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0  0.180190  0.242697 -0.194851  0.201026  0.263533 -0.174016  0.159355
# 1 -0.189119 -0.130076 -0.484334 -0.169438 -0.110395 -0.504015 -0.189119
# 2 -0.451449 -0.451449 -0.451449 -0.451449 -0.451449 -0.451449 -0.451449
# 3  1.150362  1.150362  1.072747  1.208574  1.169766  1.092151  1.208574
# 4 -1.506069 -1.486859 -1.563696 -1.506069 -1.486859 -1.563696 -1.506069
#
#     pixel_7   pixel_8   pixel_9  ...  pixel_119991  pixel_119992  \
# 0  0.242697 -0.215687  0.055176  ...     -0.257358     -0.194851
# 1 -0.130076 -0.504015 -0.149757  ...     -0.208800     -0.149757
# 2 -0.451449 -0.451449 -0.451449  ...     -0.253808     -0.431685
# 3  1.189170  1.092151  1.189170  ...      0.859303      0.839899
# 4 -1.486859 -1.563696 -1.506069  ...      0.741400      0.875864
#
#    pixel_119993  pixel_119994  pixel_119995  pixel_119996  pixel_119997  \
# ...

# %%
data.columns
# Out:
# Index(['pixel_0', 'pixel_1', 'pixel_2', 'pixel_3', 'pixel_4', 'pixel_5',
#        'pixel_6', 'pixel_7', 'pixel_8', 'pixel_9',
#        ...
#        'pixel_119991', 'pixel_119992', 'pixel_119993', 'pixel_119994',
#        'pixel_119995', 'pixel_119996', 'pixel_119997', 'pixel_119998',
#        'pixel_119999', 'label'],
#       dtype='object', length=120001)

# %%
data['label']
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 781    0.0
# 782    0.0
# 783    0.0
# 784    0.0
# 785    0.0
# Name: label, Length: 786, dtype: float64

# %%
x=data.drop(['label'],axis=1)
y=data['label']

# %%
data_values = data.values
print(data_values.shape)
# Out:
# (786, 120001)

# %%
from sklearn.model_selection import train_test_split
#Write Your Code Below:



x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)
print('x_train.shape : ',x_train.shape, y_train.shape)
print('x_test.shape : ',x_test.shape, y_test.shape)

(x_train, y_train),(x_test, y_test)=(x_train/255, y_train),(x_test/255, y_test)

#print(x_train.dtypes,y_train.dtypes)
# Out:
# x_train.shape :  (628, 120000) (628,)
# x_test.shape :  (158, 120000) (158,)

# %%
print('Unique Labels : ',data['label'].unique(), '\nNumber of classes :', len(data['label'].unique()))
# Out:
# Unique Labels :  [1. 0.]
# Number of classes : 2

# %%
x_train.shape[0]
# Out:
# 628

# %%
x_train.shape[1]
# Out:
# 120000

# %%
x_test.shape[0]
# Out:
# 158

# %%
x_train_reshaped = np.array(x_train).reshape(-1,200,200,3)
x_train_reshaped.shape
# Out:
# (628, 200, 200, 3)

# %%
x_test_reshaped = np.array(x_test).reshape(-1,200,200,3)
x_test_reshaped.shape
# Out:
# (158, 200, 200, 3)

# %%
x_train_reshaped[2]
# Out:
# array([[[0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         ...,
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193]],
#
#        [[0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         ...,
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193]],
#
#        [[0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         ...,
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193],
#         [0.00276193, 0.00276193, 0.00276193]],
#
#        ...,
#
#        [[0.00276193, 0.00276193, 0.00276193],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Ensure x_train_reshaped is within the correct range and of the correct data type
# Assuming x_train_reshaped has values in the range [0, 1] due to normalization
x_train_display = (x_train_reshaped * 255).astype(np.uint8)

# Plotting the images
f, ax = plt.subplots(2, 5, figsize=(15, 6))  # Adjust figure size for better visibility

k = 0
for i in range(2):
    for j in range(5):
        # Display the image
        ax[i, j].imshow(x_train_display[k])
        ax[i, j].axis('off')  # Hide the axis
        k += 1

plt.tight_layout()
plt.show()

# %%
model=tensorflow.keras.Sequential()
model.add(Conv2D(10 , (3,3) , strides = 1 , padding = 'same' , activation = 'relu' , input_shape = (200,200,3)))
model.add(tensorflow.keras.layers.Flatten())
#model.add(keras.layers.Dense(1000,activation='relu',kernel_initializer='he_normal'))
#model.add(keras.layers.Dense(1000, activation='relu',kernel_initializer="he_normal"))
model.add(tensorflow.keras.layers.Dense(10 , activation='relu',kernel_initializer="he_normal"))
model.add(tensorflow.keras.layers.Dense(26, activation='softmax',kernel_initializer="he_normal"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 200, 200, 10)      280
#
#  flatten (Flatten)           (None, 400000)            0
#
#  dense (Dense)               (None, 10)                4000010
#
#  dense_1 (Dense)             (None, 26)                286
#
# ...
# Total params: 4000576 (15.26 MB)
# Trainable params: 4000576 (15.26 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',
              optimizer='sgd',
              metrics=['accuracy']
)

# %%
x_train_reshaped = np.array(x_train).reshape(-1, 200, 200, 3)
x_test_reshaped = np.array(x_test).reshape(-1, 200, 200, 3)

# Convert labels to numpy array and reshape to match the number of samples
y_train_reshaped = np.array(y_train)
y_test_reshaped = np.array(y_test)

history = model.fit(
    x_train_reshaped,
    y_train_reshaped,
    epochs=50,
    batch_size=16,
    validation_data=(x_test_reshaped, y_test_reshaped),
    verbose=1
)
# Out:
# Epoch 1/50
# 40/40 [==============================] - 12s 282ms/step - loss: 1.3027 - accuracy: 0.5000 - val_loss: 0.7588 - val_accuracy: 0.3797
# Epoch 2/50
# 40/40 [==============================] - 8s 203ms/step - loss: 0.7358 - accuracy: 0.5303 - val_loss: 1.0306 - val_accuracy: 0.6203
# Epoch 3/50
# 40/40 [==============================] - 10s 250ms/step - loss: 0.7146 - accuracy: 0.5844 - val_loss: 0.7148 - val_accuracy: 0.6203
# Epoch 4/50
# 40/40 [==============================] - 8s 208ms/step - loss: 0.6990 - accuracy: 0.5812 - val_loss: 0.6910 - val_accuracy: 0.6203
# Epoch 5/50
# 40/40 [==============================] - 9s 211ms/step - loss: 0.7085 - accuracy: 0.5971 - val_loss: 0.6832 - val_accuracy: 0.6203
# Epoch 6/50
# 40/40 [==============================] - 9s 230ms/step - loss: 0.6843 - accuracy: 0.5955 - val_loss: 0.8237 - val_accuracy: 0.3797
# Epoch 7/50
# ...

# %%
#Create a graph of loss vs epoch for train and test set.
#Write Your Code Below:

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
#Create a graph of accuracy vs epoch for train and test set.
#Write Your Code Below:

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.show()

# %%
import tensorflow as tf

# Save the model
model.save('/content/drive/MyDrive/Colab Notebooks/saved models/motorcyclevscar')

# %%
pip install huggingface_hub

# %%
from google.colab import drive
from huggingface_hub import HfApi, HfFolder

# Mount Google Drive
#drive.mount('/content/drive')

# Replace with your Hugging Face token
token = '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'
api = HfApi()
HfFolder.save_token(token)

# Download the model from Google Drive to Colab
model_path = '/content/drive/MyDrive/Colab Notebooks/saved models/motorcyclevscar'
#!cp '/content/drive/My Drive/my_model' {model_path}

# Upload the model to the repository
api.upload_folder(
    folder_path=model_path,
    repo_id='ellie3000/motorcyclevscar',
    repo_type='model'
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# saved_model.pb:   0%|          | 0.00/85.5k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# variables.data-00000-of-00001:   0%|          | 0.00/32.0M [00:00<?, ?B/s]
# fingerprint.pb:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# keras_metadata.pb:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# ...

# %%
pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 11.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 48.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# ...
